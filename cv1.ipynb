# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('baboon.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x245EF26A940>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_array = np.array(pic)
type(pic_array)
# Out:
# numpy.ndarray

# %%
pic_array.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(pic_array)

# %%
pic_red = pic_array.copy()

# %%
plt.imshow(pic_red)

# %%
plt.imshow(pic_red[:,:,1])
